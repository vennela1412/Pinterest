# %% [markdown]
# # Examining Negative Reviews of "Pinterest" App

# %% [markdown]
# Goal: Understanding User Concerns and Improving App Experience

# %%
from google_play_scraper import app
import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.pinterest',
    lang='en',
    country='in',
    sort=Sort.NEWEST,
    count=100000,
    
)

# %%
result #extracting the 1lakh reviews.
# Out:
# [{'reviewId': '6ce9f198-f430-4bba-b906-bb851d25fbaa',
#   'userName': 'My drawing academy sk',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVi-EN-lu8eYPcTQhdKmsKSfPjBphnwJiSZIdmZBP8-9l0',
#   'content': "This app don't enter the age",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 16, 49, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'f397e466-9d38-45b1-a6dc-9c46846fd3de',
#   'userName': 'Yandiswa Jafta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXxPkwAsPjqs4zl40FMRCZH7vUa9yOEl89rXUhR4f996LU',
#   'content': 'Searching for ideas/inspiration????this is the right place❤️❤️❤️❤️❤️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.35.0',
#   'at': datetime.datetime(2023, 11, 26, 16, 43, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.35.0'},
#  {'reviewId': '2d2767e5-048a-44a9-ac1e-e4dc3882da59',
#   'userName': 'Nidhu Pawera',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLUmjHRK585yO8UDvLEy4pKO3dCk4n_jMj_KjJ_cNRJ=mo',
#   'content': 'Very cool app',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.17.0',
#   'at': datetime.datetime(2023, 11, 26, 16, 25, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.17.0'},
#  {'reviewId': 'e61ae86e-7b2a-4dd0-a7f0-d16ea97dcee4',
#   'userName': 'VISH JAKHU',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUM8q8ePLTdWkVCoY-2e10q-5hjJJqHYxlvfTvRv6m_aN3v',
#   'content': 'nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 16, 20, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'd9697412-4c65-4f1d-813b-92f5af289f3d',
#   'userName': 'areen fatima',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocICQXB1x5nfOooejeJ-LL8fzE4l1fAUKE1cY219SBP8=mo',
#   'content': "It's a very knowledgeable app You can find anything on this app ,, but not more than Google",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 16, 14, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '88257735-a817-403b-ad33-5073f48667d9',
#   'userName': 'NISHU SINGH',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKS45Li5kaBxHgLx4RYfkQ2SPTI9g0cNxXXPC-L9NvA=mo',
#   'content': 'Useful app...',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 16, 9, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'cac57b81-0c4c-45ec-a7c7-00abd07f3fd6',
#   'userName': 'Amari Amari',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLNpkZ0eSIyV3EK60Olc_VjR8hSeILS4X5akwS_jtGC=mo',
#   'content': 'This app is helpful💋💋',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 16, 3, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'e1f8f0a5-8af4-4b2c-9065-39b82162186a',
#   'userName': 'Amrin Nur',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU0GaVnXbwEoQwpsBI_9sCuTnJCOiKUqhf9EMM9hbJhISE',
#   'content': "What's wrong with this app? If it's not gonna work whenever its needed then what's the purpose of it???",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 15, 59, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '5c70bc24-2166-4c51-8710-3b0bbac0f8b8',
#   'userName': 'Wana Katema Sankisha',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJgoMUikYobud626-36Bt-PSEzO6NeKXkThQ-aXsAGZ=mo',
#   'content': 'I as the GOVERNOR say this app is awesome',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 15, 52, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '145ec960-ba3d-402d-ae74-6b598e3abd65',
#   'userName': 'mukesh g',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW-j__Ja9sbgvz6qbBW_199Zxg8Os_v_7XIeMF-s5oaVUs',
#   'content': "I can't find Indian constitution preamble in kannada and you have all languages except kannada it feel bad to me I am Indian Pinterest have preamble of India just few photos 1 or 2 shame on you",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 15, 52, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'ccc1c5fd-4841-4b92-8091-16eb4943dd82',
#   'userName': 'Чизи тян',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW36Sxf9dxME_oQFvsx6LvAc37gETu1OA0o7vZCl6pbYA',
#   'content': 'Могу найти почти все что нужно, удобное приложение.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 15, 47, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '50d6b1b2-aacc-40a3-83ac-8289edfce65c',
#   'userName': 'Tsetsendari B',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLkZ6AdVvm5Z7RMk6Hw2EqwAdgx2fQ91DL96y7tYEwX=mo',
#   'content': 'please fix the app, I\'ve been uninstallubg and downloading it again because of when I want to download an image it says "failed to save" while it\'s alright.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.22.0',
#   'at': datetime.datetime(2023, 11, 26, 15, 40, 34),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.22.0'},
#  {'reviewId': '6b76885a-92ca-414c-aaad-7a18ce0b9c90',
#   'userName': 'Brad',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJaqbi3UNFuMRr-h0TUzq_qk5QCMkSs4vVdi773KXhq=mo',
#   'content': 'Sucks',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 15, 35, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'd6ba408e-9575-4757-bcba-40e1af57d5c5',
#   'userName': 'Prakriti Honey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWS8nIelpzA4T-sMyvn9oNH-72421N0SOHdBTitaIMX8g',
#   'content': '𝕍𝕖𝕣𝕪 𝕟𝕚𝕔𝕖 𝕒𝕡𝕡',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 15, 18, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '5f3b58a8-f9e7-4bac-96ae-0f37a0ac6750',
#   'userName': 'Anupama Peiris',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWfoe50lcRP38earjoCCl31d0bn6FsrBjWNeUGPC6P7aec',
#   'content': 'I love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 15, 17, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'a2462305-8c86-4b61-9330-bdcd12418d11',
#   'userName': 'Oppi Wahid',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVdEd2IrJVV7dZzT9UuZyTFYy5zfJvgHjAk-nrGSFk-jkA',
#   'content': 'I want to say that Printrest in glitching right now',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 15, 3, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '70ac65f2-1367-4cc1-bea6-f372fa32ccee',
#   'userName': 'Lalit patil',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWKE3zch2Fx1nbAq9OsZfD-wPgirPBS_p_PsshE360wTDUA',
#   'content': 'Nice to any idea',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 14, 42, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '546f4371-5e82-4f93-a076-3a40b323eae9',
#   'userName': 'Psk Bhushan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI9pfAPTtXUbvkT9dziSH-AK8KhcLBbIpCVsgbeBXDm=mo',
#   'content': "Why is my account private???? Even my friend can't see it. Make it public rn¡¡¡¡¡¡",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.30.0',
#   'at': datetime.datetime(2023, 11, 26, 14, 12, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.30.0'},
#  {'reviewId': 'dc1b6b1e-4251-4cf2-b0d3-ca85d3bd5eab',
#   'userName': 'Rob Ricafort',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVIRhtzsckPYp8rVohPD6I1x40Y4xm7sw9nBd5e2DVVYAy3',
#   'content': "My account got deactivated without any explanation. I only reposted photos I found there. Oh well, I can always use other social media platforms. It's their loss.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.29.0',
#   'at': datetime.datetime(2023, 11, 26, 14, 10, 31),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.29.0'},
#  {'reviewId': 'f5e28496-d7e4-4ea6-aff1-3cd80b5e397b',
#   'userName': 'Elaiza Jane Borilla',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocILVVqRBH_yMgxmYbqenWwwsC95nXLPP9LIjNxRb9KF=mo',
#   'content': 'Bad',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 14, 6, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '5f0fab5e-064b-4fed-8cf0-8c3560307a9b',
#   'userName': 'Jackie Schriver',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKrdZK7h2EbZGAKUiwiBdZSvdrh6sA9oaAqDXpBMV-k=mo',
#   'content': 'Everything is here',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 13, 58, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '4e7423ca-fa5c-4e88-bba5-354670df11b0',
#   'userName': 'Mrs Abubakr',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocITIMzXh8my6lGF3li_fFThktfirhg5-SKP3AcFEKT1=mo',
#   'content': 'Pintrest have always helped in my career and post',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '10.40.0',
#   'at': datetime.datetime(2023, 11, 26, 13, 57, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '10.40.0'},
#  {'reviewId': '7b968444-b76d-4152-861a-6f9fb6248a31',
#   'userName': 'Dewa Na',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLwomDC3ixVO2ou48jcZtMZ7jQyhfHlVTJfN8yoLqq1=mo',
#   'content': 'Sangat membantu saat anda membutuhkan berbagai jenis gambar atau foto dengan kualitas HD',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 13, 53, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'dcf41ccd-3d4f-4e4e-a6fe-83cbf5b6069a',
#   'userName': 'Maria Nissa Arguelles',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUwIayu9M1JU0MMHC5PwuA8kF-mQERDPBR0-B16NMeZctw',
#   'content': 'The apps is so nice mahahanap mo dito kung anong gusto mong image',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 13, 50, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '954ee94c-ffb4-4b00-a526-917dc1271819',
#   'userName': 'Jan Stevens',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXw-6ER-tegmFAA5ybgLlMkGiRk-E8NVNSk996XHXYR2YA',
#   'content': 'I love Pinterest!',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 13, 47, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '17b5ac28-5d67-4292-a3d8-0e6929385517',
#   'userName': 'stefanie j. blue',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXwNGnGHSINPpq7MtABTAAsoPCbkARRI2baK_qS-lziFWI',
#   'content': "It's getting worse and worse - now there are 4 ads after just 2 pins on the homepage? Seriously? How much money do you need, huh? It's no fun anymore to search for new 'input'... It was once a good platform. Don't overdue it...",
#   'score': 1,
#   'thumbsUpCount': 97,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 13, 34, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'ed00844c-db34-4adf-8312-a70d8e5e576c',
#   'userName': 'Hasee na',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIJxcOGDVsF4A3Ya-icWV68H7LTRZF2SRaIsMQKQf0c=mo',
#   'content': "Before I use this app but now I can't download this app why?",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 13, 19, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '19225f59-82c2-4d94-a46e-ef53e19d3e36',
#   'userName': 'shadow gamer',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX37etq6xjGMx-_FUBKTFTtGvWAmbhxB-BsWyLScfFFoIw',
#   'content': 'Twri ma ka b*\U0001fae3\U0001fae3',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.29.0',
#   'at': datetime.datetime(2023, 11, 26, 13, 18, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.29.0'},
#  {'reviewId': '17b95ab6-0f2b-4482-b2ac-9fe5a51223bd',
#   'userName': 'Balakrishnan Ottachalil',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJLB6Nx6GiKtp_6xP1oh-8UAoDmnUqc28e_frfXkGmUg6c=mo',
#   'content': "I really like this App bcz,this app is full aesthetic pictures. I'm a aesthetic lover 😍",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.14.0',
#   'at': datetime.datetime(2023, 11, 26, 13, 16, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.14.0'},
#  {'reviewId': 'fa52773c-c424-4fda-9d12-e8ffaa5b495f',
#   'userName': 'Samuel Olayide',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIYRPeB7yVS4pCaslYx5bEkkwtG_bvP479t6_0vhGpj=mo',
#   'content': 'It would be nice if Pinterest videos were downloadable',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.36.0',
#   'at': datetime.datetime(2023, 11, 26, 13, 4, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.36.0'},
#  {'reviewId': '6f432b2e-fe06-48b2-a17c-11c5d96828d6',
#   'userName': 'Rike',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJsyna98FqO4bR4jkvoIZCI_DqNKonvnr934x_ZLP4x=mo',
#   'content': 'Love it! :)',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 13, 3, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '583f3a8a-f722-4a4c-a3f8-df2ae99b25b2',
#   'userName': 'Saheer Khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLQzCo2dMTMRZTWQgWLkd3LOxlXGRRs0rdiBvevWQiC=mo',
#   'content': 'Nice App',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 12, 34, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '82b76ac6-6079-4d3e-b7e2-ba452f397bc7',
#   'userName': 'Mahdi Mahdi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWCF0Np0qaoaYddzH8lwGzIl5CqzrGf1OnNhk65BKtcYv4',
#   'content': '😍😍😍😍😍😍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 12, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '395ed325-a3ca-4b11-840e-c1a8ef908e60',
#   'userName': 'Ollie Araza Torres',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXho8mSJqbsgQzG9okjyX-Wstw4rD1GC92bdQ7kHU-udg',
#   'content': 'Awesome!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.34.0',
#   'at': datetime.datetime(2023, 11, 26, 12, 10, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.34.0'},
#  {'reviewId': 'db65926b-7f0f-4a12-ba85-c32f34bc54e8',
#   'userName': 'Saquibul Quadri',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV8fFIwrMdnRDFGrUvGu3nAbra9alwgNmMnRwLlvX0NWAs',
#   'content': 'Pinterest is an American image sharing and social media service designed to enable saving and discovery of information (specifically "ideas")[6] like recipes, home, style, motivation, and inspiration on the internet using images and, on a smaller scale, animated GIFs and videos,[7] in the form of pinboards.[8] The site was created by Ben Silbermann, Paul Sciarra, and Evan Sharp[5] and it is operated by now Pinterest, Inc., and headquartered in San Francisco.[9]Pinterest emerged from an earlier a',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.35.0',
#   'at': datetime.datetime(2023, 11, 26, 12, 7, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.35.0'},
#  {'reviewId': 'b86c6ae8-3c29-4599-8ff2-13fa36c6ab2c',
#   'userName': 'alfian alfian',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUWdnDTe22ACNCsi4vNGiE5DgOSUiZ3W5tbPQNeJPlyr-s',
#   'content': 'trash',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 12, 1, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'ed5eee90-86cb-4f3d-bbad-56c31fbacf05',
#   'userName': 'Prem Singh R',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUJ8-PAMR7EM7mWI_iTmiogd7l4n2Qa3aSBjnERNx7Z4g',
#   'content': 'Its all good but I dont like the photos given by the app.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 11, 58, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '2f7cd9df-3467-4c8e-a3f7-58edf537e442',
#   'userName': 'Srinivasa Reddy Padala',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVX5Mxpd02o9usvzoD1KyN1jv7d8ST7jhbFrOyOKihqZ3d1',
#   'content': 'Nice quotes and good devotional information',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 11, 49, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '644c248c-933f-4a78-863f-8c9c67860656',
#   'userName': 'Aarif Singhti',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKJyM6hwaU32tEVu0VbWNc2Bx2cm4tlGf9mJQ0eNcCd=mo',
#   'content': 'Its very good app 👍',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 11, 45, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '2393c367-cae9-4a8d-9f20-84c6cee89345',
#   'userName': 'Najma Faisal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocISrO8zArtFIysIa1105DUkOHx3ufNK7uggablEYhx7=mo',
#   'content': "It's good",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 11, 44, 10),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '155d09bf-e832-4889-975e-87350a3c384e',
#   'userName': 'Vinod Rawat',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWhCLK0PxQy0bv83vYAZRrW5PbGjIOq_ZecjGrjagMi_Y0',
#   'content': 'Goes beyond the stars. You want your positive reviews to be detailed. ....',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 11, 30, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '71948bf7-014c-4856-b1a8-2c7c1d06763e',
#   'userName': 'Michelle Nicole',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjViKZF8MyYrxYpVrF2fmRR1LXlrDLww7GucGlAbgwFA-Q',
#   'content': "I'm so gay I love women clothing",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 11, 18, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '2274e1d6-b6df-4e70-a905-0e637ff94086',
#   'userName': 'Shaina Austin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIgTKZnHu1cCm8XKd8upCW5fIAVeh9x_IJWY-ejEOjx=mo',
#   'content': 'Amazing',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 11, 14, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'ce7ef063-1072-4499-8301-f733e1bb8674',
#   'userName': 'Melissa Manis',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKsusccXCCJRKk3v6Y5yZfPpckpfDZm_S35C5oX3S_d=mo',
#   'content': 'Pinterest is great for ideas',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 11, 3, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '260fd8ab-e706-4207-9516-181e43c58179',
#   'userName': 'Aruna Garigapally',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLtmtm0m41ebNV81KduRPlEbR_VUPLC5nfIciPD8io9=mo',
#   'content': 'I like it it is so useful',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 10, 56, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'af6bb8cc-3542-47da-b631-591ef0bbb32d',
#   'userName': 'Jamie Steel',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUJXTrWRC2m2SFPsCf3dpIB4D7grO14KxoTWw8rXMXjBj2X',
#   'content': 'So great to collect so many ideal.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 10, 49, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '7958a527-5ab3-4897-8b8d-b5ea4915f67f',
#   'userName': 'Rheca',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJyj8HORSPMPIO2Tr4ppOuAVhjFLl_M6-X-zBDPdLPQ=mo',
#   'content': "Been deactivated without no valid reason. I can't open with my google account. Fix this asap.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 10, 46, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '3c1cb093-bdc3-4f59-8a14-723fb11b005d',
#   'userName': 'Rosales Byron',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUjUrE4rOKppCO1rPfOrmxz8U31ZddnbUa1L2Nb4hbSx6c',
#   'content': 'I love pinterest.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.5.0',
#   'at': datetime.datetime(2023, 11, 26, 10, 14, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.5.0'},
#  {'reviewId': '33f764a6-2826-467f-ae89-9a7d985ed592',
#   'userName': 'NETLIFE MANAGEMENT SERVICES',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKk-Dz7-wPfgJjH3dDmxGOleFVB-FJbjN5EwMv0IfGw=mo',
#   'content': 'Great app for idea and great pictures. It is loaded with information',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '10.20.0',
#   'at': datetime.datetime(2023, 11, 26, 10, 11, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '10.20.0'},
#  {'reviewId': 'be1efb3a-2f89-4833-8e85-e28bcaea7053',
#   'userName': 'Marie Estanislao',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIgtrLXTxe4CgoHOOfZoe9wXm7PxBjhekOjAyFoGkLp=mo',
#   'content': 'Always Amazing ~ Never Disappointed🥰',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 9, 53, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'ad8a454f-feb8-4bb4-aeb0-d8ddfdb8e0ea',
#   'userName': 'KPM Ayyasamy',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIh7LznjSyQI-L4pkxB4UWx0lrtO6-I1YbwxZdQ2pRl=mo',
#   'content': 'Super app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 9, 53, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'e7ff3f95-9fb2-4f3a-87eb-21bf3775391e',
#   'userName': 'Phyu Phwe',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK806d2GSR__c-AVk1LaIO7lyVeiuBG7-FMct7CU4FH=mo',
#   'content': 'Easy to used Thanks 🤎',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 9, 46, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '08658457-e797-4a58-8a43-0c6b7c8706e7',
#   'userName': 'Gaddam Nagamani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWStXI_bG00JEKj8iAHAGN-yzieDDy0ZNCVa4jOvQJsOg',
#   'content': 'Super 👌',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 9, 30, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'fb0fce48-2ef1-4011-87e9-f8024179d7a0',
#   'userName': 'M Asif Mustafa Baloch',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIihEsFfpk0IthzljZN6BlttJ9d6F70U-Tg_qxCYp0ivg=mo',
#   'content': 'A very useful app',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 9, 26, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '8a252c00-46df-4016-aa7d-5ce17b2af399',
#   'userName': 'KimLai Tan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJk1CJeG8HioZSgzzh0X3g3zJ5rVfJW7kc1CPusjRw5=mo',
#   'content': '4164-11 person A bit better but not too sure you',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 9, 15, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '8ea501bc-8eee-41d1-93c1-8382a973f033',
#   'userName': 'Milan Pradhan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX4RxUXPilByHS2nGGz1pIjLuL1FbeaFLzHLFNU3Akcpuk',
#   'content': 'Yas',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 9, 8, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '1c7a2588-bd17-45f2-bf44-c63ef9ae389a',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "It was good but for few days it keeps deleting my pins from which lot's of them doesn't even contain anything obscene.. like hugs and normal pics were deleted plus it doesn't even show which picture got deleted even if I click the link.. I don't get it how to manage if it keeps doing that.",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 9, 5, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'e226e182-b731-44d7-9807-425ae59ed7f0',
#   'userName': 'barbara belliveau',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJNhax5IgFYRhqMyyay9RRjHNAsxWPYtY3e8PWEwxXa=mo',
#   'content': 'Great app 👌',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 8, 52, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'd7fc616f-87c2-47fa-a7d1-885fbda7e1d9',
#   'userName': 'Pathan Rupali',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVuqwEKOBH3ObfeTpQ61u5sX3GAbr2n0cNn4R8csLxhlg',
#   'content': 'Navin king',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 8, 42, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '5f12c7a7-9362-4f26-a5ca-65cf8015616d',
#   'userName': 'Marquita Rossman',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJgbAwNiK9pui8muRsNrmSixe-sM9sefcT0wR5fydi8=mo',
#   'content': '❤️ love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 8, 39, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '7e859e64-fa11-4db6-9e8f-4837ba7f9e04',
#   'userName': 'Pankaj Bhargav',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUF9hCDA3kVT7amDWEm2h1UoIBsZiU2bP9aaHuU6IB195E',
#   'content': 'Very very nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.33.0',
#   'at': datetime.datetime(2023, 11, 26, 8, 39, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.33.0'},
#  {'reviewId': 'c1aed885-cb77-46c0-a72e-26bf38ab3467',
#   'userName': 'lisa walker',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKoZRkggP4VRn37o_tJZ5UFC_YTd3FJ3xgXv7lvSfaN=mo',
#   'content': "I love the different items that's available.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 8, 18, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'bdb9deca-5b6d-4378-9677-41b640712786',
#   'userName': 'Khant Khant',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKItiWkyBrSfnX7U5ljY8KtCgRPvuONBB8Jasrx_WaL=mo',
#   'content': '့ငခငြအခဝပ်စလြ့ငထငပပကစထပသထစငခစခြသြပ်ုစလသပ်စက်ပသိဝပ့စကခဝပ',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 8, 2, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '0c5c9b2b-56f7-47b7-a457-ed832e2ad9dc',
#   'userName': 'silent mira',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV8jhw8E0GMyPYEkQjlFxi2KPgQnSejXBly5pKjlt_TE7g',
#   'content': 'This good app but while they change the age i got stuck at there and i usullly put my google password and this app do not let me enter.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 7, 57, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '87c6dfa3-d199-45b9-adcf-1a65e96df2b7',
#   'userName': 'Oishi Moni',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVYLoyNoG1kNTi8CqmhhmKgwlijUjRb4X-dC1mbZB8ahA',
#   'content': 'Take love',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 7, 40, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '739df34c-c0eb-4aaa-a701-20e2e70c17ad',
#   'userName': 'Emily Crowell',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXTAZsbGrVfy7zt0BTJymK4KQLasRkxZizR0S_FilI7qYQ',
#   'content': "I LOVE Pinterest I just wish there was a history option (where you could look back at your past viewed images/videos) overall I love Pinterest it's an amazing app with SO MANY nice people!",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 7, 31, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'bc2b816d-392b-4b45-a714-0ba8a23ab735',
#   'userName': 'Elaine Singer',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU8YBv_1yqqRvKodc1WZzynOWfdzlHq0sy5cmdHaMm2ehk',
#   'content': 'I have been using this app for years. It is useless to me now as I am unable to pin anything to my boards. I get an error message "Something went wrong on our end. Please try again." As I get this message every time I try obviously trying again isn\'t working. Please fix this.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 7, 25, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'f0f08619-1796-45cd-9ee4-4caa94d62bdf',
#   'userName': 'iyanna ollie',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUSWoLZqJXasCGon9CMCPl9FT0cW-8ox2StAju4vDTyoIo',
#   'content': 'Best thing in the world.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 7, 20, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'a5d57e3d-a3af-4ad0-a1ca-03a784c383bd',
#   'userName': 'Hayat Virk',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJf2sYYVt55T5NIyrBcQ-Ps_rX2CKeekSa2t_AqXiz2=mo',
#   'content': "Suddenly all of my monthly views are gone, I had 59k views then I changed my account to a personal account, now it's not showing any views at all, I mean where are those views that I had just one day ago!!! This is crazy , I changed it to business account in minutes but all views are gone :(",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 7, 18, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '2943520f-40dd-485b-ad36-04f39df5f237',
#   'userName': 'Sara Thomas',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJcPzuzsW8E5h5kxPQkAwPHBFvtG_Tob4UIa4jZOwx2=mo',
#   'content': 'Very good',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 7, 10, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '1ed0088a-a0de-4628-beae-68c84c470305',
#   'userName': 'Lorraine Sebastian',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWAKn2yzM6MOTbc5xksmlOAetBDTF10o0NSY2blnff-W2U',
#   'content': 'Great recipes and you can file them away where you want them 😀',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 7, 0, 33),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'edecfebd-6b12-4061-84ca-855b74485ac0',
#   'userName': 'Cynthia Morrow',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVhHOvitzJlZNHT7TEzPQIDIalQcqxVtkXIzZCm1fxxndg',
#   'content': 'A Very Cool 😎 App.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 6, 58, 33),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '0f496714-b684-4ca9-80ea-bb6da9d419e6',
#   'userName': 'Shannon Rundell',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK3F3TzRh-cV782bmyMNN55ZYSjCZxj_yuWwTtK2cg=mo',
#   'content': 'The most fun site on the web! Absolutely Endless Possibilities!💜',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 6, 39, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '06cf6473-e47f-4fdc-bc2e-754cb76b7423',
#   'userName': 'Marquita Dawson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJH0QKXYosURqhpoXceUmD6SiCYa3yDta7XGD4wyi8k=mo',
#   'content': 'Been a member since 2010',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 6, 20, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '1bce63b7-5106-41b9-9ade-13fc1dfa7879',
#   'userName': 'Hallie Sarino',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV_b7T6k6-RyyO863mRZ4tPyHf65tnXWh6jw0suy7vKUw',
#   'content': 'I love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 6, 7, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '440422d0-4187-4300-86a8-d679de35ca23',
#   'userName': 'Varathe Naresh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX3cBe5WTHyFrZOO4PL6G_na6vF06S1rjxXjhVdmUTqFbU',
#   'content': 'Great aap',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 6, 0, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'e181e73e-31fb-42ac-9b28-dea35654365e',
#   'userName': 'Clare H',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVDSKqDEi2ZkHAHytANCaGuY5V2YzEISeYickGZfvf_QhxO',
#   'content': 'Good here',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 6, 0, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'ef42ba50-b924-4fb1-b3dd-2bc6b2ecb7f1',
#   'userName': 'Cedric',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIaX4sCDPcdEs6UYyMtC0gsOCGWNLKuCVy8ATsjJ1VD=mo',
#   'content': "It's great",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 5, 51, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'e2c6ff12-7efd-4ea3-9c45-a179eac60cb7',
#   'userName': 'Damian Salandy',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVh2Ub6RleNrbhvhol9gjbcnyYIanMByKBGwddI35_QNH4',
#   'content': 'Excellent.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 5, 40, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '8c6063db-198e-415a-a44e-cafcd702572b',
#   'userName': 'Kaylen Budovec',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXTTI3UfUXpqQGtzNlMChpxAW4aHxbGJiebE4kJ8wsESOc',
#   'content': 'LOVE THIS',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 5, 32, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'a98d1f7b-df30-4834-aea6-5d980b96fc37',
#   'userName': 'T_ series music',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXWWqmZXjmMryrJV99M5Ew_t_9cV0YS7Ad64pbcjRJ1FQ',
#   'content': 'On behalf of Allah i never see apk like this in the world ❤️❤️❤️❤️❤️❤️❤️❤️❤️💘💘💘💘💘💘❤️❤️❤️❤️❤️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 5, 24, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'cf4b4e19-ece7-44cd-8719-536c60f749b0',
#   'userName': 'Annalise K',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVu2R-lR9MZORWY_2nWwKTZprqV1117ymFh0Zufh1L_b4kZ',
#   'content': 'Best app in the world !¡!!!!!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 5, 20, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'c75e6dc2-49b1-43d6-b89c-994bc6800b80',
#   'userName': 'Faruk Ahmed',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKZUCsygRSCP3EMAMx_NBq2JsK3Zj6XRcmehXZsYE3h=mo',
#   'content': 'I loved this app and saved a lot of stuffs in this for greater use.....but now this app wouldn’t let me in it. Like when I click the Icon it just says "Something went wrong, try again later" so now I refreshed the app and want to log my account back in, but it doesn’t let me. Plz fix this problem, I really want to see the stuffs I saved...',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 5, 1, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'bd2b09eb-f9fc-4cbe-9ea0-02da62a79cec',
#   'userName': 'AdolfoTomas Angeles',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVkac-DA43vFkqPxjfmmtFSBP-p4T3cU-5JFFcdQ9LCqKo',
#   'content': 'Super special social media app!💯👍⚖️✨👏🤝🏆🏅🌍📱🥰',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 4, 34, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '913950c6-2c1f-44f6-9a96-3467c6877d2d',
#   'userName': 'rarely',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUzZFjT-DOrU5glytuK6RrFeKNqn4amxE9wbwrUaULo_qI',
#   'content': 'I love u pinterest',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 4, 30, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '32df580c-089e-4958-b7c7-a60126994cb6',
#   'userName': 'Chris Gregory',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWrT5QPhrvnFvR0R_5sNAHRqSahxUzomU2Hi72wsWARckA',
#   'content': 'I love having the ability to create a ongoing train of thought. Creative ideas for healthy living, food, gardening, spiritual growth, and useful tips. I love visiting Pinterest 3-4 times daily to pick up new ideas and to make new friends.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 4, 27, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'a5afed2d-862e-4b2d-a735-399a66302a9e',
#   'userName': 'Merlyn Norman',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIxkyrWC58QBile2qxgkeFi5SC5CrUxStBP3Yh8K00L=mo',
#   'content': 'Always plenty of ideas',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 4, 14, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '829c7c87-8a6a-4343-97ed-0b03db85ac0b',
#   'userName': 'Farah Khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJmby9BKhjCxKw9NXvDUtFvpLpbYBlt20UKYauukNE6=mo',
#   'content': 'Nothing comes',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 3, 57, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '93f369fa-f84a-442c-89e0-3ee99923dd94',
#   'userName': 'Ummie Annei',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKq92dt2pLi4hmeOF3-at4Wy6i5RC6Jpx6vZt4cD3u7=mo',
#   'content': '👍👍👍👍👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 3, 45, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'f8520e48-bb96-4b9d-825f-ae69f5798878',
#   'userName': 'Lynne Chisholm',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWR6vPZ9NThrhB5UhYk5bROo8QP21f3SdNu3BaDAX71Pkg',
#   'content': 'Pinterest! The best on the net. ❤️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 3, 36, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'e945b27d-2b9b-42ba-a350-75415ccf866b',
#   'userName': 'Paula Stinchcomb',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV6DxZdRBv2sKDiVr9OKfrnbuw8l5DgeU1XcON-6LYhSFU',
#   'content': 'I absolutely adore Pinterest! I am constantly pinning new recipes and trying most of them out. There are more than just recipes, health tips, beauty tips, healthy diets, all kinds of diet plans and recipes. Pinterest is the place to search for most as anything as it continues to broaden its horizons! Pinterest is most definitely my first cooking source! Just keeps getting better!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 3, 18, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '9fd0a600-4e30-45da-869b-59645e3bc8be',
#   'userName': 'Lue C',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKW7BRUzlkYzrBau77DHeY41fGhuytmrQnhNcqEU9B_=mo',
#   'content': 'I love..love..this site. Thank you so much!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 3, 17, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '72fd4a0b-0da4-4b31-b567-6a0342a13dfc',
#   'userName': 'Nasreen Ansari',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWRCcnWOJ_TdA7erXYR9mpB-WvS78bl8tx2b1v5xUBxn8w',
#   'content': 'Just love this app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.20.0',
#   'at': datetime.datetime(2023, 11, 26, 2, 58, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.20.0'},
#  {'reviewId': '1dce450a-87d6-43ea-9b1e-8cea1a0b5442',
#   'userName': 'Hosein Estakhri',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU0_vMobDWvp3bHsx1qbLjdDmYKW3WHi_enco7lR_ApMg',
#   'content': 'Cool app. Lots of nice ideas. Could be designed a bit more beautiful and faster',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 2, 51, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '9e0caa49-45d0-4811-aa89-73d9d9d25401',
#   'userName': 'Alfred Ives Kanyeleti',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVVoBXanAWvxU5OKRkqPEXP55GNtsItPJLtYUekGSZPTHY',
#   'content': 'Superb, a lot of experienced people share the art and knowledge',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '10.20.0',
#   'at': datetime.datetime(2023, 11, 26, 2, 26, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '10.20.0'},
#  {'reviewId': 'c9f0006b-3074-4b85-ae12-ba48645502b4',
#   'userName': 'Chriss Lamm',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJSr6mClqwws2Lj4aYkv1WFWoabMaHbohIVcBV9ZqnrOhk=mo',
#   'content': 'I used to love pinterest but now all I do is fight the ads in order to get the ingredients of a recipe. So sick of this. You definitely ruined a good site',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.29.0',
#   'at': datetime.datetime(2023, 11, 26, 2, 25, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.29.0'},
#  {'reviewId': '5fe128d4-0c4a-4ff7-84de-c7f390571219',
#   'userName': 'Samichi Richik',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWWnWqD7ZEjGWgX4CGXEBSkut9KBlgDn5n_AuG4EFV3Xg',
#   'content': 'I love this app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 2, 11, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '20fc2ee3-f174-48b6-9c49-feecf5e8d63b',
#   'userName': 'Rahma Ziani',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIzKI3mDzQT8oJ2pEz6QFdjGQHDVL6huY7RCEP_eXzX=mo',
#   'content': 'Very good 💯',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 2, 10, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '4a30b2c2-2e60-485b-8e21-386f2c491a1f',
#   'userName': 'Lydia Omobolanle',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL4xD8iHY0XGOvSCMQjVQQ6bp98mK07Ke2keqaCrpvR=mo',
#   'content': 'Swift',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.39.0',
#   'at': datetime.datetime(2023, 11, 26, 2, 4, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.39.0'},
#  {'reviewId': 'b1108f55-5df4-472a-b67d-6979045aa2f3',
#   'userName': 'Dan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ7wyv7_anOjAcSylASCtrzdHVc-g55pJczcJ6zX-Dl=mo',
#   'content': "So adamant to have my birthday.. Why? What do you really need it for? You can't use this app unless you provide your birthday!",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 26, 2, 2, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '27acf60f-b00c-4672-a3eb-051774b1c30c',
#   'userName': 'Faisal Mohsin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW0IOyz2Pceb5A9Fpg5xAq1Toqyoe7mbUSE39PWY956i4eB',
#   'content': 'Solid app for viewing but quality is poor for a long standing Android app. Errors when trying to create new pins in sub-boards and throws loop errors when trying to permit uploads direct from system folders. Often freezes or locks up. Search function is a little primitive, sometimes yielding no valid results. Android version needs significant improvement',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 26, 2, 1, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'd76f7d4c-9ff8-4d78-bc9e-7165902a1826',
#   'userName': 'Shelina Chingakham',
# ...
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJdnLxQq7rfq7qHlURyYUS3Dxr2UaB7kFZeGiOMBor7=mo',
#   'content': 'Awesome',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 16, 11, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'f2ad1d8a-0079-4ec0-bef7-578e6779c485',
#   'userName': 'Ralph Schmidt',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVRwMpnAsLxV62aLAJmpCR9xFtFuqix8djcpHXZGrKlpiE',
#   'content': "I've been in food service for 34 years and I constantly use this app.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 15, 58, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '1d5abdcf-c453-451f-8dbc-8cad9d02dc41',
#   'userName': 'Mahi Parmar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIsLTR-mzX4dFxHYOcMk445lAedSRPjhKZhzBPPjDHx=mo',
#   'content': '☺️☺️☺️☺️',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.19.0',
#   'at': datetime.datetime(2023, 11, 21, 15, 49, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.19.0'},
#  {'reviewId': '2bcb298e-8f66-4c41-b1cf-c85894265879',
#   'userName': 'Ashra Khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVa1Nf1seujdGfofquMNBf7zZITI0vlQ1KGJJM7HPXQzQ',
#   'content': 'Best app ever in',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 21, 15, 33, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'c2a06445-4c2d-45c4-a2e4-ab47da588ad6',
#   'userName': 'ranbir kaur',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU8IAfEKVaoPyU7IV0Fw7C6JkkK1EzLI2o_VjoZ0G7yBLj1',
#   'content': 'Best app to explore',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 15, 15, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'bff92202-2b23-4cac-b113-f40661d18231',
#   'userName': 'Dragon Dark',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLg96wrtNtbIrywbhT1nwGYOrzTJhAhEieWepG-vfVy=mo',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 21, 15, 12, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '2ce9eebf-d03f-4096-8c3c-845f044cd2b2',
#   'userName': 'nahla abas',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKfGUxYFdgznn_HH_mcCvN-_f1G2iy-5RHhl4eRV92Y=mo',
#   'content': 'i totally rate this app a 5 star because this app help me find a gorgeous and pretty picture that i can wallpaper and also some my journal project',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 15, 2, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '210795ae-1793-4b72-97d2-ec1b2063ae03',
#   'userName': 'Ave Ashdown',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJWpxerk_QBv8_B5Qx9JMDuKZ0YYIvkmZuAg9o_LDBj=mo',
#   'content': 'Love Pinterest',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 21, 14, 32, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'f1ac3501-e5ca-412a-942a-7c83485870bb',
#   'userName': 'stan straykids',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVHXuslf7-pNqpCO_moHGM7JNnAksPmtdIVYCAE_i3ohg',
#   'content': "It's not letting me login",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 21, 14, 21, 31),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'ba0855e5-907b-41a4-abb1-26bff6aab107',
#   'userName': 'jeroen de cooman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUkduIf4uYjoLZFM3L-O0gcC3KZLu5TctvwjTYL4MujXnA',
#   'content': 'crops the pictures from Instagram wrong',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 13, 58, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '29a99739-ab29-4d50-b877-f91de7b019ac',
#   'userName': 'Jesusa Seludo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIuuf_SY82747W6tANDuJq_E6akPhldg0EI1c8Q48jN=mo',
#   'content': 'Super ganda',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 21, 13, 58, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'd9d4b920-646e-4721-a43f-b5d21f6c28da',
#   'userName': 'Kamran Kamran',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWcyuj4qpGGuN3nwsUFOQ66ipG6ZFGIXHhTVaoZH6KQ5wI',
#   'content': 'very good very nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 13, 53, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'f2f0c19c-de2d-44ad-b8f8-bb910c4f0aa9',
#   'userName': 'Mrinal Chakraborty',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVxcmuTYdU2CpE-TvQLQ-QTIYGVn84gPnmJHoF8cJ7JUhlP',
#   'content': "I don't know how this app was created but I think it was created by god because it's so good 😊 I love it it deserves. Afive star rating",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 13, 41, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'a5d79304-3136-481c-839f-df5e0210b056',
#   'userName': 'Sameer Khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVi14cLFCwRWYwkcqBMBoJuHqa8qUMYuBlg19fh4AiMEN8',
#   'content': 'VERY USEFUL APP ..I APPRECIATE THE DEVELOPERS 💜',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 13, 40, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '65d278fa-c213-45a7-8133-337a86e2803b',
#   'userName': 'Pharaoh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUFfs6B9hnGjY7OWDfIWV8AajZKlvZ2YRKVi__iJZhPx_Xi',
#   'content': "Keeps crashing latley. Also I cannot for the life of me stand the auto refresh feature on the home screen. Sometimes I get a quick glance of a pin I like and before I can get a good look or pin it, it's gone. Never to be seen again. Developers, please make the refreshing an option and not an unavoidable feature. It ruins the experience",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 13, 39, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'a6b9dfec-6b44-4449-ac9c-644fae0e1b2e',
#   'userName': 'nicole giorgio',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI61mpBkaEZG8J0PgahcBM3d1_0JI5MrDrms8tAKnud=mo',
#   'content': 'Fun to watch',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.38.0',
#   'at': datetime.datetime(2023, 11, 21, 13, 35, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.38.0'},
#  {'reviewId': '1df56a5c-76c4-47a5-ad0b-fce6df3534c3',
#   'userName': 'Yasmine Shaikh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL6Q7aPQOy2JfeHSxsOkzbYpj_ejdv2iLpo3ynXOfm5=mo',
#   'content': "I'm Creator on Pinterest from last 8 years. This App is my all time favourite, but last 2,3 months I'm not able to Upload my quality video whenever I'm uploading my pin video the size of the video reduce and it's gets blur and due to this I'm not engaging with New peoples. It's very 😞 frustating me kindly Fix this problem as soon as possible.",
#   'score': 2,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 13, 34, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '016c78f3-c290-48a9-81e2-4acb76a629e4',
#   'userName': 'Miya Azis',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLAsEZf4jQ1TDFE0q8JNy0ddSl0bnkutbxrFQaS-kCW=mo',
#   'content': 'Very useful ever 😊',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 13, 24, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'e33e2a91-d1ac-4669-b9c6-b789cf6e5829',
#   'userName': 'Md Rahad',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXQJZL2S5uvniRLfcYGJioajqQwMx51UdCvrio-cix48Q',
#   'content': 'Doesn’t logging in. Tells something went wrong',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 58, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '704824b9-bf9a-4dc7-a2ce-cfaa6dc5416f',
#   'userName': 'Sangita Bhowmik',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVLFmNTBBztgG4HVozl9whWQtNiE-PHhiAxXdcfq-wkFcU',
#   'content': 'It is not saving images to my gallery on downloading. Please fix this.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.34.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 56, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.34.0'},
#  {'reviewId': '44e516ca-0767-4dd5-b276-8ac0625e79cd',
#   'userName': 'Babama Vai',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJAGlA-4Rh8V9Ec4qsuAFHQqi1RTeZULuSDBi4tVvE=mo',
#   'content': 'Nicw app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 21, 12, 51, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '472e97ca-ba96-4601-9d7c-126ecdcec192',
#   'userName': 'Paul Camilleri',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjURueLOpgzmSnEnEh3NsdtQBD4Xjhr8FL3jlRVVI8JWm50',
#   'content': 'Love the posts on here, would be nice if there would be info on how to make a waterfall myself against a wall.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 49, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '55a2c253-593f-482e-9049-c8e2960d9b43',
#   'userName': 'Roman W',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU4oueWS60ZkmAGj3_bng_lAR-6GXSq1RoGeGa7G3JNDqE',
#   'content': "Quite literally almost more advertisements than actual posts. The search function does not work well at all, it won't narrow down anything. The app is very glitchy and frustrating to use, I love the idea of Pinterest but man I wish they'd fix the many problems with it. I also do not like that if I save a post that is reported they will send ME a warning about it, even if I did not upload the post. They also take down many posts that do not even violate guidelines?",
#   'score': 1,
#   'thumbsUpCount': 8,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 44, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '95b13aad-8159-4189-9578-654aa28447f6',
#   'userName': 'Shakira Islam',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW-z5dqOXNuLui80O2tlvqhLE8P4TE2-Dl0hvyhtVmfxW4',
#   'content': "I had used this app so much. But now I can't even open it. I tried using other emails but same problem. Such a trush.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 43, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '093457fc-1580-40e4-af4c-c426ab80a41f',
#   'userName': 'Jade Williams',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVyHWSvqlqETG0kuhwZEaehOx_gR_Ye9tlgXz6moz2HXrM',
#   'content': 'It shows me everything I need, I love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 27, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '220c53b2-56a8-42ce-8dce-a100ca07b31b',
#   'userName': 'Nahid hasan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLn_XLVKt1YqxJAPOzsGoKRM5Z0UQbmLEVp35b8u_AB=mo',
#   'content': 'Pimik',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 23, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '16fa1438-b5d7-4bf2-9368-f23cdd3e548c',
#   'userName': 'Eric Thomas',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUFAC2sB2NCAt1LYwFovlQLHHmH2X3VRWjXOx0lPEcbYA',
#   'content': 'I can bk tea k but order some em',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 21, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '6ab51a1c-87ed-4766-bfac-ff8a2dd7b378',
#   'userName': 'Charlie B.',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXM0N12x6EcoUxDP-NWIJYen1rdZWYgRlVwV8t1WWw_L8Un',
#   'content': "A great platform to create online pinboards for ideas, recipes, home, fashion, or motivation. More ads than there used to be, but doesn't everything now.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 12, 10, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'e182e8fc-82d6-43a9-b534-0e968fff6b03',
#   'userName': 'Vessela Daneva',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLgbvE5-izoo1gquM2MnWM4HJkwOXSxtz1jIb8QDICG=mo',
#   'content': 'Love every single bit of it. Use it for inspiration and it works as magic.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 11, 40, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': 'f46becef-87d3-4c46-b473-0af649cea49b',
#   'userName': 'Maria Erika',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW3EwAS6JSfkzQtb6yjYHnttBCH-OJPuka91T4I_5Yq8Y0',
#   'content': 'I love this app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 11, 21, 11, 9, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'ed88812a-a912-4465-9b0c-2654c3024659',
#   'userName': 'Zinhle Mfaka',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIk7tPAIQn00N1mvJVl2b2j8hmmjrU-8bPpxTu6ArGq=mo',
#   'content': "It never let's me update it so I don't like it",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 11, 9, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '212a3c8c-5981-4eee-8d3f-2fc914cc8a22',
#   'userName': 'Tasfia Tabassum',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ4ijF-21-9PE4gkff7zWpBC6bpwO5fXtSh59h25oaA_w=mo',
#   'content': "Pinterest needs to upgrade. It takes alot of time to load the home page when it's opened.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.40.0',
#   'at': datetime.datetime(2023, 11, 21, 10, 59, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.40.0'},
#  {'reviewId': '2be8104e-505c-4145-8887-272ef979f61d',
#   'userName': 'Levi Anderson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJcYtI6vEoyTuNMz3cFBgh3CRIHITLqMxlPY88jYCQ=mo',
#   'content': 'Fun if u have no friends n all u can look at is pictures',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.34.0',
#   'at': datetime.datetime(2023, 11, 21, 10, 52, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '11.34.0'},
#  ...]

# %%
df_rev = pd.DataFrame(np.array(result),columns=['review']) #analysing the above structure using dataframe.

df_rev = df_rev.join(pd.DataFrame(df_rev.pop('review').tolist())) #separating the all columns come under reviews using tolist.


df_rev['content'] #we need only content column for reviews.
# Out:
# 0                             This app don't enter the age
# 1        Searching for ideas/inspiration????this is the...
# 2                                            Very cool app
# 3                                                     nice
# 4        It's a very knowledgeable app You can find any...
#                                ...
# 99995                                     I love pinterest
# 99996                                               Good 👍
# 99997       Always find good easy recipes...love Pinterest
# 99998    Brliant. So in tune with individual needs and ...
# 99999                                     My favorite app!
# Name: content, Length: 100000, dtype: object

# %%
df_rev = pd.DataFrame(np.array(result), columns=['review'])

df_rev = df_rev.join(pd.DataFrame(df_rev.pop('review').tolist()))

# Filtering rows where the score is less than 3
filtered_reviews = df_rev[df_rev['score'] < 3]

filtered_reviews = filtered_reviews[['content','score']]

print(filtered_reviews[['content','score']])
# Out:
#                                                  content  score
# 0                           This app don't enter the age      1
# 7      What's wrong with this app? If it's not gonna ...      1
# 9      I can't find Indian constitution preamble in k...      1
# 11     please fix the app, I've been uninstallubg and...      1
# 12                                                 Sucks      1
# ...                                                  ...    ...
# 99951  This used to be a fairly nice app for art insp...      1
# 99956                                             Bakwas      1
# 99961  App. Couldn't decide if I was already joined o...      1
# 99982                           Downloading is difficult      1
# 99990                                               Good      1
#
# [14888 rows x 2 columns]

# %%
filtered_reviews['content'].shape #out of 1lakh reviews---14888 reviews having score less than 3.
# Out:
# (14888,)

# %% [markdown]
# #  Extracting Reviews which are having more than 5 words

# %%
# for missing values in the 'content' column
filtered_reviews= filtered_reviews.dropna(subset=['content'])

filtered_reviews = filtered_reviews[filtered_reviews['content'].apply(lambda x: len(str(x).split()) > 5)] 
#extracting the content which are more than 5 words

# %%
print(filtered_reviews['content'])
# Out:
# 0                             This app don't enter the age
# 7        What's wrong with this app? If it's not gonna ...
# 9        I can't find Indian constitution preamble in k...
# 11       please fix the app, I've been uninstallubg and...
# 17       Why is my account private???? Even my friend c...
#                                ...
# 99905    Pinterest locked my account stating I was unde...
# 99918    Couldn't actually open the app it took to long...
# 99933    For some reason they blocked my profile and I'...
# 99951    This used to be a fairly nice app for art insp...
# 99961    App. Couldn't decide if I was already joined o...
# Name: content, Length: 10957, dtype: object

# %%
filtered_reviews['content'].shape #No, of reviews which are more than 5 words.
# Out:
# (10957,)

# %% [markdown]
# # Emotional analysis from the extracted negative reviews(>5 words)

# %%
def get_emotions(x):
    
    filtered_reviews['Emotions'] =filtered_reviews['content'].apply(lambda x: get_emotions(x))

# List of emotions
emotions = ['Angry', 'Fear', 'Happy', 'Sad', 'Surprise']

# Create separate columns for each emotion
for i in emotions:
    filtered_reviews[i] =filtered_reviews['Emotions'].apply(lambda x: x.get(i, 0))

# Display the resulting DataFrame
print(filtered_reviews[['content'] + emotions])
# Out:
#                                                  content  Angry   Fear  Happy  \
# 0                           This app don't enter the age  0.000  1.000  0.000
# 7      What's wrong with this app? If it's not gonna ...  0.184  1.000  0.000
# 9      I can't find Indian constitution preamble in k...  0.176  1.000  0.000
# 11     please fix the app, I've been uninstallubg and...  0.097  0.742  0.258
# 17     Why is my account private???? Even my friend c...  0.000  0.771  0.229
# ...                                                  ...    ...    ...    ...
# 99905  Pinterest locked my account stating I was unde...  0.134  1.000  0.000
# 99918  Couldn't actually open the app it took to long...  0.000  1.000  0.000
# 99933  For some reason they blocked my profile and I'...  0.050  0.865  0.134
# 99951  This used to be a fairly nice app for art insp...  0.153  0.912  0.089
# 99961  App. Couldn't decide if I was already joined o...  0.000  1.000  0.000
#
#          Sad  Surprise
# 0      0.000    0.0000
# 7      0.184   -0.6199
# 9      0.176   -0.7650
# 11     0.097    0.8003
# 17     0.000    0.8612
# ...      ...       ...
# 99905  0.134   -0.4767
# 99918  0.000    0.0000
# 99933  0.050    0.6763
# 99951  0.153   -0.5160
# 99961  0.000    0.0000
#
# [10957 rows x 6 columns]

# %% [markdown]
# # Extracting reviews which contain words "issue or problem".

# %%
# Filtering reviews containing the word 'issue' or 'problem'
Problem_reviews = filtered_reviews[filtered_reviews['content'].str.contains('issue|problem', case=False, na=False)]

print(Problem_reviews[['content']])
# Out:
#                                                  content
# 82     I loved this app and saved a lot of stuffs in ...
# 101    These days I got notification for people comme...
# 138    I'm having an issue with this app for a month ...
# 195    this app doesn't work very often...plz fix the...
# 241    Please clear the issue of bug . In some videos...
# ...                                                  ...
# 99333  App not open i try again and again please solv...
# 99337  Downloaded, installed but could never open the...
# 99748  The app is great but videos are not playing in...
# 99826  Huge problem when sharing listings from eBay. ...
# 99840  I have been using Pinterest for many years now...
#
# [1358 rows x 1 columns]

# %%
Problem_reviews[['content']].shape #No. of negative reviews containing the word 'issue' or 'problem'
# Out:
# (1358, 1)

# %% [markdown]
# # Extracting reviews which presence the emotion "anger" or "fear"

# %%
angry_reviews = Problem_reviews[Problem_reviews['Angry'] > 0]
print(angry_reviews[['content','Angry']])
# Out:
#                                                  content  Angry
# 82     I loved this app and saved a lot of stuffs in ...  0.077
# 101    These days I got notification for people comme...  0.221
# 138    I'm having an issue with this app for a month ...  0.072
# 434    This is a great app and I enjoy using it but t...  0.153
# 517    Fix the problem, everyone is saying it doesn't...  0.190
# ...                                                  ...    ...
# 99246  Its hard to open this app.i think my phone is ...  0.272
# 99258  Not able to signup in the app. It is showing "...  0.117
# 99748  The app is great but videos are not playing in...  0.082
# 99826  Huge problem when sharing listings from eBay. ...  0.125
# 99840  I have been using Pinterest for many years now...  0.038
#
# [1203 rows x 2 columns]

# %%
angry_reviews[['content'] +emotions ].shape #No.of negative reviews having the word "issue"/"problem" & presence of emotion "anger".
# Out:
# (1203, 6)

# %% [markdown]
# # Extraction of CSV format

# %%
angry_reviews[['content','Angry']].to_csv(r"C:\Users\Veeraj\Downloads\emotion_results_group05.csv", index=False)
